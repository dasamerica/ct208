# %%
  elements = [2,1,3,4]
  me = elements[0]
  ma = elements[0]
  ma_2 = elements[0]
  me_2 = elements[0]

  n = 1
  t= [0,0,0,0]
  while n < (len(elements)):
    # conta trocas maior
    if ma < elements[n]: 
       ma_2 = ma
       ma = elements[n]
       t[0]+=1
       t[2]+=1
    # conta trocas menor
    if me > elements [n]:
       me_2 = me
       me = elements[n]
       t[1]+=1
       t[3]+=1


    n+=1

  print(t)  
  print(ma, me, ma_2, me_2)
# Out:
# [2, 1, 2, 1]
# 4 1 3 2
